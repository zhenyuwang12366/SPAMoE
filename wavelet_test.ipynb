# %%
import pywt
import numpy as np
import torch

# %%
pywt.wavelist('haar')

# %%
import torch
torch.is_complex()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 import torch
# ----> 2 torch.is_complex_dtype()
#
# File /opt/anaconda3/envs/FWINO/lib/python3.10/site-packages/torch/__init__.py:2745, in __getattr__(name)
#    2742 if name in _lazy_modules:
#    2743     return importlib.import_module(f".{name}", __name__)
# -> 2745 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'torch' has no attribute 'is_complex_dtype'
